# %% [markdown]
# # imports and installs

# %%
# !pip install -U ultralytics
# !pip3 install torch torchvision torchaudio
from ultralytics import YOLO
from PIL import Image
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # Importing/testing pre-trained detection model

# %% [markdown]
# Segmentation:
# https://docs.ultralytics.com/tasks/segment/#dataset-format
#
# Hyperparameter tuning: https://pub.towardsai.net/understanding-hyper-parameter-tuning-of-yolos-82aec5f6e7b3

# %%
model = YOLO("./models/yolo26n.pt")

# %%
results = model("testing-imgs/room0.png",conf=0.05)
# Out:
# image 1/1 /Users/elena/Documents/GitHub/model-code/testing-imgs/room0.png: 448x640 1 chair, 1 potted plant, 1 bed, 1 book, 1 vase, 59.2ms
# Speed: 5.5ms preprocess, 59.2ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)

# %%
# Access the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Show results to screen (in supported environments)
    r.show()

    # Save results to disk
    r.save(filename=f"./testing-results/results{i}.jpg")

# %% [markdown]
# Current, pretrained model on an image of a bedroom:
#
# | Bedroom without id | Bedroom with id |
# |---|---|
# | ![bedroom img](testing-imgs/room0.png) | ![bedroom with items id'd](testing-results/results0.jpg)|

# %% [markdown]
# # Testing on video of Love It or List It
#
# https://www.youtube.com/watch?v=AYIfuyonMl4

# %%
video_track = model.track("testing-imgs/test-video.mov", device='cpu',
                           conf=0.05, save=True
                           )  # Tracking with default tracker
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1516) /Users/elena/Documents/GitHub/model-code/testing-imgs/test-video.mov: 384x640 2 couchs, 43.6ms
# video 1/1 (frame 2/1516) /Users/elena/Documents/GitHub/model-code/testing-imgs/test-video.mov: 384x640 2 couchs, 36.8ms
# video 1/1 (frame 3/1516) /Users/elena/Documents/GitHub/model-code/testing-imgs/test-video.mov: 384x640 2 couchs, 36.8ms
# ...

# %% [markdown]
# # Trying to improve model performance

# %% [markdown]
# ## Training on Open Images v7

# %%
# results = model.train(data="open-images-v7.yaml", epochs=100, imgsz=640)

# %%
modelv = YOLO("./models/yolov8n.pt")

# %%
# results = modelv.train(data="coco8.yaml", epochs=100, imgsz=640)

# %%
results = modelv("testing-imgs/room0.png",conf=0.05)
# Out:
# image 1/1 /Users/elena/Documents/GitHub/model-code/testing-imgs/room0.png: 448x640 2 potted plants, 1 bed, 1 dining table, 4 books, 1 vase, 100.2ms
# Speed: 9.4ms preprocess, 100.2ms inference, 9.1ms postprocess per image at shape (1, 3, 448, 640)

# %%
# Access the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Show results to screen (in supported environments)
    r.show()

    # Save results to disk
    r.save(filename=f"./testing-results/results{i}.jpg")

# %%
video_track = modelv.track("testing-imgs/test-video.mov", device='cpu',
                           conf=0.05, save=True
                           )  # Tracking with default tracker
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1516) /Users/elena/Documents/GitHub/model-code/testing-imgs/test-video.mov: 384x640 2 couchs, 52.0ms
# video 1/1 (frame 2/1516) /Users/elena/Documents/GitHub/model-code/testing-imgs/test-video.mov: 384x640 2 couchs, 45.6ms
# video 1/1 (frame 3/1516) /Users/elena/Documents/GitHub/model-code/testing-imgs/test-video.mov: 384x640 2 couchs, 43.2ms
# ...

# %% [markdown]
# ## OpenImagesv7

# %%
model = YOLO("yolov8n-oiv7.pt")


results = model("testing-imgs/room0.png",conf=0.05)
# Out:
# image 1/1 /Users/elena/Documents/GitHub/model-code/testing-imgs/room0.png: 448x640 1 Bed, 1 Coffee table, 1 Flowerpot, 1 House, 2 Houseplants, 3 Pillows, 1 Table, 1 Window, 108.9ms
# Speed: 8.8ms preprocess, 108.9ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)

# %%
# Access the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Show results to screen (in supported environments)
    r.show()

    # Save results to disk
    r.save(filename=f"./testing-results/results{i}.jpg")

# %%
video_track = modelv.track("testing-imgs/test-video.mov", device='cpu',
                           conf=0.05, save=True)  # Tracking with default tracker
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1516) /Users/elena/Documents/GitHub/model-code/testing-imgs/test-video.mov: 384x640 2 couchs, 61.1ms
# video 1/1 (frame 2/1516) /Users/elena/Documents/GitHub/model-code/testing-imgs/test-video.mov: 384x640 2 couchs, 57.5ms
# video 1/1 (frame 3/1516) /Users/elena/Documents/GitHub/model-code/testing-imgs/test-video.mov: 384x640 2 couchs, 33.8ms
# ...

# %% [markdown]
# ## yolov8s-worldv2

# %%
modelE = YOLO("yolov8s-worldv2.pt") 

results = modelE("testing-imgs/room0.png",conf=0.05)

# Access the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Show results to screen (in supported environments)
    r.show()

    # Save results to disk
    r.save(filename=f"./testing-results/results{i}.jpg")
# Out:
# image 1/1 /Users/elena/Documents/GitHub/model-code/testing-imgs/room0.png: 448x640 1 cup, 1 bowl, 1 potted plant, 1 bed, 1 vase, 159.9ms
# Speed: 3.9ms preprocess, 159.9ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)

# %%
video_track = modelE.track("testing-imgs/test-video.mov", device='cpu',
                           conf=0.05, save=True
                           )  # Tracking with default tracker
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1516) /Users/elena/Documents/GitHub/model-code/testing-imgs/test-video.mov: 384x640 1 bowl, 1 chair, 2 couchs, 121.2ms
# video 1/1 (frame 2/1516) /Users/elena/Documents/GitHub/model-code/testing-imgs/test-video.mov: 384x640 1 bowl, 1 chair, 2 couchs, 105.2ms
# video 1/1 (frame 3/1516) /Users/elena/Documents/GitHub/model-code/testing-imgs/test-video.mov: 384x640 1 bowl, 1 chair, 2 couchs, 90.3ms
# ...

# %% [markdown]
# ## yolo26n-seg

# %%
model = YOLO("./models/yolo26n-seg.pt")

results = model("testing-imgs/room0.png",conf=0.05)

# Access the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Show results to screen (in supported environments)
    r.show()

    # Save results to disk
    r.save(filename=f"./testing-results/results{i}.jpg")
# Out:
# image 1/1 /Users/elena/Documents/GitHub/model-code/testing-imgs/room0.png: 448x640 1 potted plant, 1 bed, 2 books, 1 vase, 127.8ms
# Speed: 8.5ms preprocess, 127.8ms inference, 45.8ms postprocess per image at shape (1, 3, 448, 640)

# %%
video_track = model.track("testing-imgs/test-video.mov", device='cpu',
                           conf=0.05, save=True
                           )  # Tracking with default tracker
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1516) /Users/elena/Documents/GitHub/model-code/testing-imgs/test-video.mov: 384x640 2 couchs, 1 tv, 82.4ms
# video 1/1 (frame 2/1516) /Users/elena/Documents/GitHub/model-code/testing-imgs/test-video.mov: 384x640 2 couchs, 1 tv, 70.7ms
# video 1/1 (frame 3/1516) /Users/elena/Documents/GitHub/model-code/testing-imgs/test-video.mov: 384x640 2 couchs, 60.3ms
# ...

# %%
from ultralytics import YOLO
from PIL import Image

# %%
model = YOLO("yolov8n-oiv7.pt")


results = model("testing-imgs/room0.png",conf=0.05)
# Out:
# image 1/1 /Users/elena/Documents/GitHub/model-code/testing-imgs/room0.png: 448x640 1 Bed, 1 Coffee table, 1 Flowerpot, 1 House, 2 Houseplants, 3 Pillows, 1 Table, 1 Window, 70.8ms
# Speed: 4.2ms preprocess, 70.8ms inference, 6.8ms postprocess per image at shape (1, 3, 448, 640)

# %%
# Access the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Show results to screen (in supported environments)
    r.show()

    # Save results to disk
    r.save(filename=f"./testing-results/results{i}.jpg")

# %%
#training on coco8 doesn't significantly improve results on sample image
# 
# # results = model.train(data="coco8.yaml", epochs=100, imgsz=640)

# %%
# results = model("testing-imgs/room0.png",conf=0.05)

# # Access the results
# for i, r in enumerate(results):
#     # Plot results image
#     im_bgr = r.plot()  # BGR-order numpy array
#     im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

#     # Show results to screen (in supported environments)
#     r.show()

#     # Save results to disk
#     r.save(filename=f"./testing-results/results{i}.jpg")

# %%
model_train = model

# %%
# from datasets import load_dataset

# ds = load_dataset("byliu/DeepFurniture")

# %%
# import scipy.io as sio
# import numpy as np
# import mat73

# data = mat73.loadmat('datasets_files/nyu_depth_v2_labeled.mat')

# print(data.keys()) 

# X = data['images']
# y = data['labels']

# %% [markdown]
# https://huggingface.co/docs/datasets/depth_estimation

# %%
# from datasets import load_dataset

# train_data = load_dataset("sayakpaul/nyu_depth_v2", split="train", streaming=True)

# %%
# first_sample = next(iter(train_data))
# first_sample['image']

# %%
from datasets import load_dataset

training_ds = load_dataset("byliu/DeepFurniture", streaming=True)
# Out:
# Resolving data files:   0%|          | 0/65 [00:00<?, ?it/s]

# %%
next(iter(training_ds['train']))
# Out:
# {'__key__': '10042806',
#  '__url__': 'hf://datasets/byliu/DeepFurniture@ea6952993f844a8ad0fcea3eb88b1892c4b8e617/data/furnitures/furnitures_0000.tar.gz',
#  'jpg': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400>}
